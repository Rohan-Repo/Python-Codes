# %% [markdown]
# # Python Assignment #1  for iNeuron

# %% [markdown]
# ### 1 - Install Jupyter notebook and run the first program and share the screenshot of the output.

# %%
name, age = input().split()
print( 'My Name is {} and my age is {}'.format(name,age) )
# Out:
# Rohan 28
# My Name is Rohan and my age is 28

# %% [markdown]
# ***
# ![Python-Assignment-1.jpg](attachment:Python-Assignment-1.jpg)
# ***

# %% [markdown]
# ### 2 - Write a program which will find all such numbers which are divisible by 7 but are not a multiple of 5, between 2000 and 3200 (both included). The numbers obtained should be printed in a comma-separated sequence on a single line.

# %%
num_list = range( 2000,3201 ) # As we want 3200 included

for i in num_list:
    if i%7 == 0 and i%5 != 0:
        print( i, end = ',' )
# Out:
# 2002,2009,2016,2023,2037,2044,2051,2058,2072,2079,2086,2093,2107,2114,2121,2128,2142,2149,2156,2163,2177,2184,2191,2198,2212,2219,2226,2233,2247,2254,2261,2268,2282,2289,2296,2303,2317,2324,2331,2338,2352,2359,2366,2373,2387,2394,2401,2408,2422,2429,2436,2443,2457,2464,2471,2478,2492,2499,2506,2513,2527,2534,2541,2548,2562,2569,2576,2583,2597,2604,2611,2618,2632,2639,2646,2653,2667,2674,2681,2688,2702,2709,2716,2723,2737,2744,2751,2758,2772,2779,2786,2793,2807,2814,2821,2828,2842,2849,2856,2863,2877,2884,2891,2898,2912,2919,2926,2933,2947,2954,2961,2968,2982,2989,2996,3003,3017,3024,3031,3038,3052,3059,3066,3073,3087,3094,3101,3108,3122,3129,3136,3143,3157,3164,3171,3178,3192,3199,

# %% [markdown]
# ### 3 - Write a Python program to accept the user's first and last name and then getting them printed in the the reverse order with a space between first name and last name.

# %%
fName, lName = input().split()
print( 'Original String : ', (fName+lName) )
print( 'Reversed String : ', (fName[ : : -1] + ' ' + lName[ : : -1]) )
# Out:
# Rohan Deshpande
# Original String :  RohanDeshpande
# Reversed String :  nahoR ednaphseD

# %% [markdown]
# ### 4 - Write a Python program to find the volume of a sphere with diameter 12 cm. (V=4/3 * π * r 3)

# %%
rad = 12/2

volSphere = (4/3) * math.pi * (rad ** 3)
print( 'Volume of a Sphere with Diameter 12cm = ', round(volSphere,2), ' cm\u00b3' )
# Out:
# Volume of a Sphere with Diameter 12cm =  904.78  cm³

# %% [markdown]
# ### 5 - Write a program which accepts a sequence of comma-separated numbers from console and generate a list.

# %%
numList = list( (input().split(',') ) )
numList = [ int(i) for i in numList ]
print( 'Generated List = ', numList )
# Out:
# 12,45,78,34,90,17
# Generated List =  [12, 45, 78, 34, 90, 17]

# %% [markdown]
# ### 6- Create the specified pattern

# %% [markdown]
# ###### Solution 1 : 2 Loops

# %%
for i in range(1,6):
    print()
    for j in range(i):
        print( '*' , end=' ')
        
for i in range(4,-1,-1):
    print()
    for j in range(i):
        print( '*' , end=' ')
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * *
# * * *
# * *
# *

# %% [markdown]
# ###### Solution 2 : List Manipulation

# %%
starList = list( range(1,6) )
# starList[ -2::-1 ]
for i in starList[ -2::-1 ]:
    starList.append( i )
    
for i in starList:
    print()
    for j in range(i):
        print( '*' , end=' ')
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * *
# * * *
# * *
# *

# %% [markdown]
# ### 7 - Write a Python program to reverse a word after accepting the input from the user.

# %%
str2 = input()
print( 'Normal String : ', str2 )
print( 'Reverse String : ', str2[::-1] )
# Out:
# AcadGild
# Normal String :  AcadGild
# Reverse String :  dliGdacA

# %% [markdown]
# ### 8 - Write a Python Program to print the given string in the format specified in the sample output.
# - WE, THE PEOPLE OF INDIA, having solemnly resolved to constitute India into a SOVEREIGN, SOCIALIST, SECULAR, DEMOCRATIC REPUBLIC and to secure to all its citizens

# %%
sampleString = "WE, THE PEOPLE OF INDIA, having solemnly resolved to constitute India into a SOVEREIGN, SOCIALIST, SECULAR, DEMOCRATIC REPUBLIC and to secure to all its citizens"

chunk1 = sampleString.split(',')
chunk1
chunk2 = chunk1[5].split('and')
print( chunk1 )
print( chunk2 )
# Out:
# ['WE', ' THE PEOPLE OF INDIA', ' having solemnly resolved to constitute India into a SOVEREIGN', ' SOCIALIST', ' SECULAR', ' DEMOCRATIC REPUBLIC and to secure to all its citizens']
# [' DEMOCRATIC REPUBLIC ', ' to secure to all its citizens']

# %% [markdown]
# ###### Solution 1 - String Concatenation

# %%
modifiedString = chunk1[0] + ',' + chunk1[1] + ',\n\t' + chunk1[2] + ', !\n\t\t' + chunk1[3] + ',' + chunk1[4] + ',' + chunk2[0] + '\n \t\t\t and' + chunk2[1]

print( 'Original String : ', sampleString )
print( 'Modified String : \n ', modifiedString )
# Out:
# Original String :  WE, THE PEOPLE OF INDIA, having solemnly resolved to constitute India into a SOVEREIGN, SOCIALIST, SECULAR, DEMOCRATIC REPUBLIC and to secure to all its citizens
# Modified String :
#   WE, THE PEOPLE OF INDIA,
# 	 having solemnly resolved to constitute India into a SOVEREIGN, !
# 		 SOCIALIST, SECULAR, DEMOCRATIC REPUBLIC
#  			 and to secure to all its citizens

# %% [markdown]
# ###### Solution 2 - F-String

# %%
modifiedString = f"{chunk1[0]},{chunk1[1]},\n\t {chunk1[2]},!\n\t\t{chunk1[3]},{chunk1[4]},{chunk2[0]}\n \t\t   and{chunk2[1]}"
print( 'Original String : ', sampleString )
print( 'Modified String : \n ', modifiedString )
# Out:
# Original String :  WE, THE PEOPLE OF INDIA, having solemnly resolved to constitute India into a SOVEREIGN, SOCIALIST, SECULAR, DEMOCRATIC REPUBLIC and to secure to all its citizens
# Modified String :
#   WE, THE PEOPLE OF INDIA,
# 	  having solemnly resolved to constitute India into a SOVEREIGN,!
# 		 SOCIALIST, SECULAR, DEMOCRATIC REPUBLIC
#  		   and to secure to all its citizens
